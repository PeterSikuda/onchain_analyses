# %% [markdown]
# ## Analyse difference in metrics Coinmetrics vs Glassnode
#
# #### coins/metrics available in both sources
#
# - AdrActCnt: ANT,BAT,BCH,BTC,CRO,CVC,DRGN,ELF,ENG,ETH,FUN,GNT,GUSD,HT,KCS,KNC,LINK,LOOM,LTC,MANA,MCO,MKR,OMG,PAY,POLY,POWR,PPT,QASH,SAI,SNT,WTC,ZRX
# - FeeTotNtv: BCH,BTC,ETH,LTC
# - TxTfrValAdjNtv: ANT,BAT,BCH,BTC,CRO,CVC,DRGN,ELF,ENG,ETH,FUN,GNT,GUSD,HT,KCS,KNC,LINK,LOOM,LTC,MANA,MCO,MKR,OMG,PAY,POLY,POWR,PPT,QASH,SAI,SNT,WTC,ZRX
# - TxTfrValMedNtv: ANT,BAT,BCH,BTC,CRO,CVC,DRGN,ELF,ENG,ETH,FUN,GNT,GUSD,HT,KCS,KNC,LINK,LOOM,LTC,MANA,MCO,MKR,OMG,PAY,POLY,POWR,PPT,QASH,SAI,SNT,WTC,ZRX
#
# Formula to calculate the Difference:
# #### - coinmetric{metric} - glassnode{metric} / coinmetric{metric}
#
#
# To get the output chart run the appropriate function in cell [2], [3], [4], [5] with following parameters
# - run cell [1]
# - asset = asset symbol in capital letters
# - start_date = starting date since the data will be plotted in format YYYY-MM-DD
#
# Hint:
# To run a cell hit the run button (or Shift + Enter) with coursor on active cell

# %%
from utils import *

# %%
json.__version__
# Out:
# '2.0.9'

# %% [markdown]
# ### Plot Daily Active Addresses

# %%
plot_AdrActCnt_diff('ETH',start_date='2017-01-01')

# %% [markdown]
# ### Plot Total Network Fees

# %%
plot_FeeTotNtv_diff('ETH','2017-01-01')

# %% [markdown]
# ### Plot Transfer volume (Total)

# %%
plot_TxTfrValAdjNtv_diff('ETH','2019-01-01')

# %% [markdown]
# ### Plot Transfer volume (median)

# %%
plot_TxTfrValMedNtv_diff('ETH','2017-01-01')
